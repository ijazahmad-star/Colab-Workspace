# %% [markdown]
# <a href="https://colab.research.google.com/github/ijazahmad-star/Colab-Workspace/blob/main/march%2027%202026/vectorless_and_vector_Rag_Comparison/Vectorless_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vectorless Rag

# %% [markdown]
# ### Install Libraries
# This cell installs the necessary Python libraries for PageIndex and LangChain integration with Google Generative AI.

# %%
# Install lib...
# !pip install pageindex
# !pip install langchain langchain-google-genai google-generativeai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Import Required Libraries
# This cell imports all the necessary Python modules for interacting with the PageIndex client, handling file operations, and making HTTP requests.

# %%
# import required lib...
import os
import json
import requests
import asyncio
from pageindex import PageIndexClient
import pageindex.utils as utils

# %% [markdown]
# ### Initialize PageIndex Client
# This cell retrieves the `PAGEINDEX_API_KEY` from Colab's user data secrets and initializes the `PageIndexClient`.

# %%
from google.colab import userdata
PAGEINDEX_API_KEY = userdata.get('PAGEINDEX_API_KEY')
pi_client = PageIndexClient(api_key=PAGEINDEX_API_KEY)

# %% [markdown]
# ### Document Download (Skipped)
# This cell was originally intended to download a PDF document from a URL. However, it's currently skipped, and a local PDF file is used instead for this demonstration.

# %%
# download the docs
# but i am using this i used my own doc

# pdf_url = "https://arxiv.org/pdf/2501.12948.pdf"
# pdf_path = os.path.join("../data", pdf_url.split('/')[-1])

# os.makedirs(os.path.dirname(pdf_path), exist_ok=True)

# response = requests.get(pdf_url)
# with open(pdf_path, "wb") as f:
#     f.write(response.content)

# print(f"Downloaded {pdf_url}")
print("SKIP")
# Out:
# SKIP

# %% [markdown]
# ### Submit Document to PageIndex
# This cell specifies the path to the PDF document, submits it to the PageIndex service for processing, and stores the returned `doc_id`.

# %%
pdf_path = "/content/Company Profile.pdf"
doc_info = pi_client.submit_document(pdf_path)
doc_id = doc_info["doc_id"]

print('Document Submitted:', doc_id)
# Out:
# Document Submitted: pi-cmn8vcdbg00k209phdew9n7y0

# %% [markdown]
# ### Check Document Processing Status
# This cell checks the status of the document submitted to PageIndex. It waits until the document processing is `completed`.

# %%
status = pi_client.get_document(doc_id)["status"]
if status == "completed":
    print('Document processing completed')
# Out:
# Document processing completed

# %% [markdown]
# ### Retrieve PageIndex Tree Structure
# This cell retrieves and prints the hierarchical tree structure of the processed document from PageIndex, if the processing is completed.

# %%
tree_result = pi_client.get_tree(doc_id)
if tree_result.get("status") == "completed":
    print("PageIndex Tree Structure:", tree_result.get("result"))
# Out:
# PageIndex Tree Structure: [{'title': 'Preface', 'node_id': '0000', 'page_index': 1, 'text': '![img-0.jpeg](img-0.jpeg)\n\nStrategistHub\n\nAccelerating Growth Through Innovation\n'}, {'title': 'Introduction', 'node_id': '0001', 'page_index': 2, 'text': "# Introduction\n\nBuilding the Future with AI at the Core\n\nAt StrategistHub, we build future-ready digital solutions with AI at the core of everything we do. We work closely with businesses to streamline workflows, improve decision-making, and create new opportunities for growth through purposeful innovation.\n\nOur team brings deep technical expertise and hands-on experience solving real-world challenges. Whether you are launching a new product or modernizing existing systems, we partner with you to turn complexity into scalable, high-impact solutions.\n\nTable of Content\n\n1. CEO Message\n2. Company Vision &amp; Mission\n3. Where We Stand\n4. Our Core Values\n5. Our Leadership Team\n6. Industries We Serve\n7. What We Do\n8. Our E
# ...

# %%
# above cell output
#{
#   "Preface": {
#     "node_id": "0000",
#     "page_index": 1
#   },
#   "Introduction": {
#     "node_id": "0001",
#     "page_index": 2,
#     "sections": [
#       "CEO Message",
#       "Company Vision & Mission",
#       "Where We Stand",
#       "Our Core Values",
#       "Our Leadership Team",
#       "Industries We Serve",
#       "What We Do",
#       "Our Engagement Models",
#       "Achievements",
#       "Client Success Stories",
#       "Customer Feedback",
#       "Let's Connect"
#     ]
#   },
#   "Message From CEO": {
#     "node_id": "0002",
#     "page_index": 4
#   },
#   "Company Vision & Mission": {
#     "node_id": "0003",
#     "page_index": 5,
#     "children": {
#       "Vision": {},
#       "Mission": {}
#     }
#   },
#   "Where We Stand": {
#     "node_id": "0004",
#     "page_index": 6,
#     "highlights": [
#       "150+ Clients",
#       "6+ Years Experience",
#       "10+ Industries",
#       "10+ Countries",
#       "Top 5% Talent",
#       "2 Global Offices"
#     ]
#   },
#   "Our Core Values": {
#     "node_id": "0005",
#     "page_index": 7
#   },
#   "Our Leadership Team": {
#     "node_id": "0006",
#     "page_index": 8,
#     "members": [
#       "Farhan Tahir (CEO)",
#       "Wajeeh Gillani (COO)",
#       "Hassan Mehmood (Engineering Head)",
#       "Rizwan Atta (Engineering Manager)",
#       "Jibran Ullah Khan (Head of Sales)",
#       "Uqba Manzoor (Digital Marketing Manager)"
#     ]
#   },
#   "Industries We Serve": {
#     "node_id": "0007",
#     "page_index": 9
#   },
#   "What We Do": {
#     "node_id": "0008",
#     "page_index": 10
#   },
#   "Our Engagement Models": {
#     "node_id": "0009",
#     "page_index": 11,
#     "models": [
#       "Project Outsourcing",
#       "Staff Augmentation",
#       "Dedicated Team"
#     ]
#   },
#   "Achievements (Q1 2025)": {
#     "node_id": "0010",
#     "page_index": 12,
#     "highlights": [
#       "20+ new hires",
#       "Digital Marketing Manager hired",
#       "New client accounts",
#       "AI-first engineering training",
#       "Delivered AI-powered products"
#     ],
#     "workflow": {
#       "Requirement Identification": { "node_id": "0011" },
#       "Strategic Planning": { "node_id": "0015" },
#       "Engineering & Development": { "node_id": "0016" },
#       "Quality Assurance": { "node_id": "0017" },
#       "User Acceptance Testing": { "node_id": "0014" },
#       "Deployment": { "node_id": "0013" },
#       "Maintenance & Support": { "node_id": "0012" }
#     }
#   },
#   "Case Studies & Client Wins": {
#     "node_id": "0018",
#     "page_index": 14,
#     "cases": {
#       "Aura Health": {
#         "focus": [
#           "UI redesign",
#           "AI emotion intelligence",
#           "Platform upgrade",
#           "New monetization features"
#         ],
#         "tech_stack": [
#           "Next.js",
#           "React",
#           "Node.js",
#           "Postgres",
#           "Stripe",
#           "Firebase",
#           "Heroku",
#           "OpenAI",
#           "Hume AI"
#         ]
#       },
#       "Keller Williams": {
#         "focus": [
#           "Legacy modernization",
#           "Mobile app",
#           "Financial system",
#           "Globalization",
#           "Marketplace",
#           "Messaging system"
#         ]
#       },
#       "ChainList": {
#         "focus": [
#           "MVP development",
#           "Full-stack solution",
#           "AI integration"
#         ]
#       },
#       "TryHackMe": {
#         "focus": [
#           "Tech stack upgrade",
#           "Migration strategy",
#           "System understanding"
#         ]
#       }
#     }
#   },
#   "Let's Connect": {
#     "node_id": "0021",
#     "page_index": 19,
#     "contact": {
#       "email": "contact@strategisthub.com",
#       "website": "www.strategisthub.com",
#       "phone": "+1 (415) 8004207",
#       "location": "Austin, TX, USA"
#     }
#   }
# }

# %% [markdown]
# ### Wait for Document Indexing (Commented Out)
# This cell contains commented-out code that would wait for the document to be fully indexed by PageIndex. It's included to show the process, but typically, `get_document`'s status check might suffice or stream chat completions handle the wait internally.

# %%
# import time

# print(f"Waiting for document {doc_id} to be indexed...")

# max_retries = 30
# retry_count = 0

# while not pi_client.is_retrieval_ready(doc_id):
#     if retry_count >= max_retries:
#         print("Timeout: Document processing took too long.")
#         break

#     print(f"Still processing... (Attempt {retry_count + 1}/{max_retries})")
#     time.sleep(5)
#     retry_count += 1

# if pi_client.is_retrieval_ready(doc_id):
#     print("Success! Document is ready.")
#     tree = pi_client.get_tree(doc_id, node_summary=True)['result']
#     utils.print_tree(tree)
# else:
#     tree = None

# %% [markdown]
# ### Configure Google Generative AI LLM
# This cell configures the Google Gemini LLM (`gemini-2.5-flash`) with a specified temperature and retrieves the API key from Colab's user data secrets.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

# os.environ["GOOGLE_API_KEY"] = "your_google_api_key"
from google.colab import userdata
gapi_key=userdata.get('GOOGLE_API_KEY')

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.3,
    api_key=gapi_key,
)

# %% [markdown]
# ### Define PageIndex Retrieval Function
# This function `retrieve_from_pageindex` takes a query and document ID, submits the query to PageIndex, waits for the retrieval to complete, and extracts relevant content from the top `k` retrieved nodes.

# %%
import time

def retrieve_from_pageindex(query, doc_id, top_k=3):

    response = pi_client.submit_query(
        doc_id=doc_id,
        query=query
    )

    retrieval_id = response.get("retrieval_id")
    if not retrieval_id:
        return []

    while True:
        retrieval = pi_client.get_retrieval(retrieval_id)
        status = retrieval.get("status")

        if status == "completed":
            break
        elif status == "failed":
            return []

        time.sleep(1)

    nodes = retrieval.get("retrieved_nodes", [])
    contexts = []

    for node in nodes[:top_k]:
        relevant_contents = node.get("relevant_contents", [])

        for group in relevant_contents:
            for item in group:
                content = item.get("relevant_content")
                if content:
                    contexts.append(content)

    return contexts

# %% [markdown]
# ### Define Vectorless RAG Function
# This function `vectorless_rag` orchestrates the RAG process. It retrieves contexts using `retrieve_from_pageindex` and then constructs a prompt for the LLM to answer the query based *only* on the provided context.

# %%
def vectorless_rag(query, doc_id):

    contexts = retrieve_from_pageindex(query, doc_id)

    if not contexts:
        return "No relevant context found."

    combined_context = "\n\n".join(contexts)

    prompt = f"""
    You are a research assistant.
    Answer ONLY using the context below.
    If the answer is not found, say "Not found in document."

    Context:
    {combined_context}

    Question:
    {query}
    """
    response = llm.invoke(prompt)
    return response.content

# %% [markdown]
# ### Chat with Document using PageIndex (Non-Streaming)
# This cell demonstrates a direct chat completion with the document using the PageIndex client, asking for key findings. The response is printed once fully generated.

# %%
# Chat with a specific document
response = pi_client.chat_completions(
    messages=[
        {"role": "user", "content": "What are the key findings in this document?"}
    ],
    doc_id=doc_id
)

print(response["choices"][0]["message"]["content"])
# Out:
# I'll analyze the document to extract the key findings for you. Let me start by checking the structure.## Key Findings from StrategistHub Company Profile
#
# **Company Overview & Positioning**
# - AI-centric digital solutions provider with **6+ years of experience**
# - Specializes in AI-driven digital transformation to help businesses streamline operations and accelerate growth
# - Leadership team includes experienced professionals in engineering, operations, and sales
#
# **Scale & Global Reach**
# - **150+ satisfied clients** across diverse industries
# - Serving **10+ industries** and **10+ countries**
# - **2 global offices** with top 5% in-house talent
# - Team composition focused on exceptional software engineers and innovators
#
# **Core Capabilities**
# - **Services**: Custom Software Development, UI/UX Design, AI/ML, MVP Development, On-Demand Engineers, DevOps, Application Modernization, Support & Maintenance
# ...

# %% [markdown]
# ### Stream Chat Completions with Document
# This cell shows how to use PageIndex's chat completions with streaming enabled, allowing the response to be printed incrementally as it's generated.

# %%
from pageindex import PageIndexClient

# Streaming chat with document
for chunk in pi_client.chat_completions(
    messages=[
        {"role": "user", "content": "Summarize this document"}
    ],
    doc_id=doc_id,
    stream=True
):
    print(chunk, end='', flush=True)
# Out:
# {"query": "select:mcp__pageindex__get_document_structure,mcp__pageindex__get_page_content", "max_results": 2}{"doc_name": "Company Profile.pdf"}{"doc_name": "Company Profile.pdf", "pages": "2-7"}{"doc_name": "Company Profile.pdf", "pages": "9-13"}{"doc_name": "Company Profile.pdf", "pages": "14-16"}## Summary of Company Profile
#
# **StrategistHub** is an AI-centric digital solutions company focused on building future-ready technology that drives business growth and innovation.
#
# ### Company Overview
# - **Experience**: 6+ years in software development
# - **Global Reach**: 150+ satisfied clients across 10+ industries and 10+ countries
# - **Team**: Top 5% in-house talent with 2 global offices (including Austin, TX)
# - **Leadership**: Led by CEO Farhan Tahir with a team of experienced professionals
#
# ### Vision & Mission
# - **Vision**: Become the trusted global partner for AI-driven digital transformation
# ...

# %% [markdown]
# ### Test Vectorless RAG with Irrelevant Query
# This cell tests the `vectorless_rag` function with a question that is not expected to be found in the document, demonstrating how it handles out-of-context queries.

# %%
# irrelvant question , to check how much it takes time.
query = "What is the main contribution of this paper?"
start = time.time()
answer = vectorless_rag(query, doc_id)
end = time.time()
print(f"Time taken: {end - start} seconds")

print("\nFINAL ANSWER:\n")
print(answer)
# Out:
# Time taken: 18.299107789993286 seconds
#
# FINAL ANSWER:
#
# Not found in document.

# %% [markdown]
# ### Test Vectorless RAG with General Query
# This cell tests the `vectorless_rag` function with a general question about 'StrategistHub' to extract information from the document.

# %%
query = "tell me about strategisthub?"
start = time.time()
answer = vectorless_rag(query, doc_id)
end = time.time()
print(f"Time taken: {end - start} seconds")

print("\nFINAL ANSWER:\n")
print(answer)
# Out:
# Time taken: 13.188035488128662 seconds
#
# FINAL ANSWER:
#
# StrategistHub builds future-ready digital solutions with AI at its core. They work with businesses to streamline workflows, improve decision-making, and create new growth opportunities through purposeful innovation. Their team has deep technical expertise and hands-on experience solving real-world challenges, partnering with businesses to turn complexity into scalable, high-impact solutions for new products or modernizing existing systems.
#
# StrategistHub's team consists of exceptional software engineers and forward-thinking innovators who set the benchmark in software development. They work across various industries, delivering outstanding results with full-time dedication. Beyond projects, they are passionate about nurturing new talent, opening career pathways, and guiding young professionals toward success in a dynamic global landscape.

# %% [markdown]
# ### Test Vectorless RAG with Specific Query
# This cell tests the `vectorless_rag` function with a specific question about the CEO and their long-term direction statement.

# %%
query = "who is the ceo of strategisthub and his Long-Term Direction Statement"
start = time.time()
answer = vectorless_rag(query, doc_id)
end = time.time()
print(f"Time taken: {end - start} seconds")

print("\nFINAL ANSWER:\n")
print(answer)
# Out:
# Time taken: 11.971147537231445 seconds
#
# FINAL ANSWER:
#
# Farhan Tahir is the CEO of StrategistHub. His Long-Term Direction Statement emphasizes growth, innovation, and effective problem-solving as core professional values. He is deeply committed to quality and excellence, aiming to create lasting impact.

# %% [markdown]
# ### Test Vectorless RAG with Company Statement Query
# This cell tests the `vectorless_rag` function with a query about the company's long-term direction statement.

# %%
query = "what is company Long-Term Direction Statement"
start = time.time()
answer = vectorless_rag(query, doc_id)
end = time.time()
print(f"Time taken: {end - start} seconds")

print("\nFINAL ANSWER:\n")
print(answer)
# Out:
# Time taken: 14.333983182907104 seconds
#
# FINAL ANSWER:
#
# At StrategistHub, we envision a future where businesses thrive through intelligent innovation. Our goal is to become the trusted global partner for AI-driven digital transformation and helping businesses to drive potential, lead markets, and build scalable impact in a rapidly evolving tech landscape.

# %% [markdown]
# # Vector Rag

# %% [markdown]
# ### Install LangChain Libraries for Vector RAG
# This cell installs additional `langchain` components required for setting up a traditional vector-based RAG system.

# %%
# !pip install langchain_community  langchain_openai langchain_faiss
# Out:
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.19
#     Uninstalling langchain-core-1.2.19:
#       Successfully uninstalled langchain-core-1.2.19
# ...

# %%
# !pip install langchain-classic

# %%
# !pip install pypdf faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 33.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Import Libraries for Vector RAG
# This cell imports necessary classes from `langchain_community`, `langchain_text_splitters`, `langchain_openai`, and `langchain_classic` to build a vector RAG pipeline.

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_openai import ChatOpenAI
from langchain_classic.chains import RetrievalQA

# %% [markdown]
# ### Load, Split Document and Create Vector Store
# This cell loads the PDF document, splits it into smaller chunks using `RecursiveCharacterTextSplitter`, generates embeddings using `OpenAIEmbeddings`, and stores them in a FAISS vector database. Finally, it creates a retriever from the vector store.

# %%
loader = PyPDFLoader("/content/Company Profile.pdf")
documents = loader.load()

from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
docs = text_splitter.split_documents(documents)
embeddings = OpenAIEmbeddings(api_key=OPENAI_API_KEY)

vectorstore = FAISS.from_documents(docs, embeddings)
retriever = vectorstore.as_retriever()

# %% [markdown]
# ### Define Prompt Template for Vector RAG
# This cell defines a `PromptTemplate` specifically for the vector-based RAG approach, instructing the AI to answer strictly based on the provided context.

# %%
from langchain_core.prompts import PromptTemplate
prompt_template = """
You are an AI assistant that answers questions ONLY based on the provided context.

Rules:
- Use only the given context to answer
- If the answer is not in the context, say "I don't know based on the document"
- Do not make up information
- Keep answers clear and concise
- Check sementically

Context:
{context}

Question:
{question}

Answer:
"""

PROMPT = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)

# %% [markdown]
# ### Initialize LLM and RetrievalQA Chain
# This cell initializes the `ChatOpenAI` LLM (`gpt-4o-mini`) and sets up the `RetrievalQA` chain, connecting the retriever and the LLM with the defined prompt.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

# os.environ["GOOGLE_API_KEY"] = "your_google_api_key"
from google.colab import userdata
gapi_key=userdata.get('GOOGLE_API_KEY')

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.3,
    api_key=gapi_key,
)

# %%
# llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3, api_key= OPENAI_API_KEY)
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type_kwargs={"prompt": PROMPT}
)

# %% [markdown]
# ### Test Vector RAG with Irrelevant Query
# This cell tests the vector RAG setup with a question that is not contained in the document to observe its behavior in such scenarios.

# %%
import time
query = query = "What is the main contribution of this paper?"

start = time.time()
result = qa_chain.run(query)
end = time.time()
print(f"Time taken: {end - start} seconds")

print(result)
# Out:
# Time taken: 1.4537651538848877 seconds
# I don't know based on the document.

# %% [markdown]
# ### Test Vector RAG with General Query
# This cell tests the vector RAG setup with a general query about 'StrategistHub' to verify its ability to retrieve and synthesize information.

# %%
import time
query = "tell me about strategisthub?"

start = time.time()
result = qa_chain.run(query)
end = time.time()
print(f"Time taken: {end - start} seconds")

print(result)
# Out:
# Time taken: 3.3764913082122803 seconds
# StrategistHub builds future-ready digital solutions with AI at its core, working with businesses to streamline workflows, improve decision-making, and create new growth opportunities through purposeful innovation. They transform complex challenges into scalable opportunities using AI-powered strategies and deep technical expertise.
#
# Over the past decade, StrategistHub has evolved into a globally recognized technology partner, serving clients across industries and continents. They have 150+ satisfied clients, 6+ years of experience, and have served 10+ countries. Their headquarter is in Austin, USA, and their development center is in Lahore, PAK.
#
# StrategistHub is led by visionary professionals with deep industry expertise and a passion for innovation. Their goal is to become the trusted global partner for AI-driven digital transformation, helping businesses thrive through intelligent innovation.

# %% [markdown]
# ### Test Vector RAG with Company Statement Query
# This cell tests the vector RAG setup with a query about the company's long-term direction statement.

# %%
query = "what is company Long-Term Direction Statement"
start = time.time()
result = qa_chain.run(query)
end = time.time()
print(f"Time taken: {end - start} seconds")

print(result)
# Out:
# Time taken: 1.5001540184020996 seconds
# At StrategistHub, we envision a future where businesses thrive through intelligent innovation. Our goal is to become the trusted global partner for AI-driven digital transformation and helping businesses to drive potential, lead markets, and build scalable impact in a rapidly evolving tech landscape.

# %% [markdown]
# ### Test Vector RAG with Company Vision Statement Query
# This cell tests the vector RAG setup with a query specifically asking for the company's vision statement.

# %%
query = "what is company vission statement"
start = time.time()
result = qa_chain.run(query)
end = time.time()
print(f"Time taken: {end - start} seconds")

print(result)
# Out:
# Time taken: 1.756072998046875 seconds
# At StrategistHub, we envision a future where businesses thrive through intelligent innovation. Our goal is to become the trusted global partner for AI-driven digital transformation and helping businesses to drive potential, lead markets, and build scalable impact in a rapidly evolving tech landscape.
